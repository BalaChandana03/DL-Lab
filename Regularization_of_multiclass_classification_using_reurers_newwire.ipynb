# %% [markdown]
# <a href="https://colab.research.google.com/github/BalaChandana03/DL-Lab/blob/OIBSIP/Regularization_of_multiclass_classification_using_reurers_newwire.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
from keras.datasets import reuters

# %%
(train_X, train_Y), (test_X, test_Y) = reuters.load_data(num_words=10000)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/reuters.npz
# 2110848/2110848 [==============================] - 0s 0us/step

# %%
import numpy as np
from keras.utils import to_categorical

def OneHotEncoding_fn(ReutersData, dimension=10000):
    # 8982 x 10k matrix of zeros
    OneHotEncoded_Data = np.zeros((len(ReutersData), dimension))
    for i, sequence in enumerate(ReutersData):
        #Selectively make indices as 1 based on availability of word in the review.
        OneHotEncoded_Data[i, sequence] = 1.
    return OneHotEncoded_Data

x_train = OneHotEncoding_fn(train_X)
x_test = OneHotEncoding_fn(test_X)

y_train = to_categorical(train_Y)
y_test = to_categorical(test_Y)

# %%
from keras import models
from keras import layers
from keras import regularizers

model = models.Sequential()
#model.add(layers.Dense(64, activation='relu', input_shape=(10000,)))
#model.add(layers.Dense(64, kernel_regularizer=regularizers.l1(0.001), activation='relu', input_shape=(10000,)))
#model.add(layers.Dense(64, kernel_regularizer=regularizers.l2(0.01), activation='relu', input_shape=(10000,)))
model.add(layers.Dense(64, kernel_regularizer=regularizers.l1_l2(l1=0.001, l2=0.01), activation='relu', input_shape=(10000,)))

#model.add(layers.Dense(64, activation='relu'))
#model.add(layers.Dense(64, kernel_regularizer=regularizers.l1(0.001), activation='relu'))
#model.add(layers.Dense(64, kernel_regularizer=regularizers.l2(0.01), activation='relu'))
model.add(layers.Dense(64, kernel_regularizer=regularizers.l1_l2(l1=0.001, l2=0.01), activation='relu'))

model.add(layers.Dense(46, activation='softmax'))

# %%
from keras import optimizers
from keras import losses
from keras import metrics

X_validation = x_train[:800]
X_train_without_val = x_train[800:]
y_validation = y_train[:800]
y_train_without_val = y_train[800:]


model.compile(optimizer=optimizers.RMSprop(learning_rate=0.001, rho=0.9),
             loss=losses.categorical_crossentropy,
             metrics=[metrics.categorical_accuracy])

history = model.fit(X_train_without_val,
                    y_train_without_val,
                    epochs=25,
                    batch_size=512,
                    validation_data=(X_validation,y_validation))
# Out:
# Epoch 1/25
# 16/16 [==============================] - 1s 44ms/step - loss: 7.1589 - categorical_accuracy: 0.4853 - val_loss: 3.6962 - val_categorical_accuracy: 0.5475
# Epoch 2/25
# 16/16 [==============================] - 1s 32ms/step - loss: 3.3626 - categorical_accuracy: 0.5620 - val_loss: 3.0842 - val_categorical_accuracy: 0.6000
# Epoch 3/25
# 16/16 [==============================] - 1s 46ms/step - loss: 3.0268 - categorical_accuracy: 0.6057 - val_loss: 2.8716 - val_categorical_accuracy: 0.6313
# Epoch 4/25
# 16/16 [==============================] - 1s 42ms/step - loss: 2.8412 - categorical_accuracy: 0.6377 - val_loss: 2.7200 - val_categorical_accuracy: 0.6587
# Epoch 5/25
# 16/16 [==============================] - 1s 39ms/step - loss: 2.6994 - categorical_accuracy: 0.6573 - val_loss: 2.5835 - val_categorical_accuracy: 0.6687
# Epoch 6/25
# 16/16 [==============================] - 0s 31ms/step - loss: 2.5918 - categorical_accuracy: 0.6640 - val_loss: 2.4902 - val_categorical_accuracy: 0.6775
# Epoch 7/25
# 16/16 [==============================] - 0s 30ms/step - loss: 2.4974 - categorical_accuracy: 0.6689 - val_loss: 2.4011 - val_categorical_accuracy: 0.6825
# Epoch 8/25
# 16/16 [==============================] - 0s 29ms/step - loss: 2.4163 - categorical_accuracy: 0.6775 - val_loss: 2.3381 - val_categorical_accuracy: 0.6787
# Epoch 9/25
# 16/16 [==============================] - 0s 30ms/step - loss: 2.3528 - categorical_accuracy: 0.6804 - val_loss: 2.3153 - val_categorical_accuracy: 0.6888
# Epoch 10/25
# 16/16 [==============================] - 0s 29ms/step - loss: 2.2972 - categorical_accuracy: 0.6836 - val_loss: 2.2564 - val_categorical_accuracy: 0.6888
# Epoch 11/25
# 16/16 [==============================] - 0s 30ms/step - loss: 2.2517 - categorical_accuracy: 0.6871 - val_loss: 2.1891 - val_categorical_accuracy: 0.6963
# Epoch 12/25
# 16/16 [==============================] - 0s 30ms/step - loss: 2.2084 - categorical_accuracy: 0.6896 - val_loss: 2.1550 - val_categorical_accuracy: 0.6950
# Epoch 13/25
# 16/16 [==============================] - 0s 31ms/step - loss: 2.1829 - categorical_accuracy: 0.6871 - val_loss: 2.1287 - val_categorical_accuracy: 0.6963
# Epoch 14/25
# 16/16 [==============================] - 0s 31ms/step - loss: 2.1431 - categorical_accuracy: 0.6914 - val_loss: 2.1150 - val_categorical_accuracy: 0.6975
# Epoch 15/25
# 16/16 [==============================] - 1s 37ms/step - loss: 2.1223 - categorical_accuracy: 0.6931 - val_loss: 2.0766 - val_categorical_accuracy: 0.7000
# Epoch 16/25
# 16/16 [==============================] - 1s 53ms/step - loss: 2.0955 - categorical_accuracy: 0.6951 - val_loss: 2.0589 - val_categorical_accuracy: 0.6975
# Epoch 17/25
# 16/16 [==============================] - 1s 31ms/step - loss: 2.0777 - categorical_accuracy: 0.6953 - val_loss: 2.0410 - val_categorical_accuracy: 0.7013
# Epoch 18/25
# 16/16 [==============================] - 0s 30ms/step - loss: 2.0611 - categorical_accuracy: 0.6945 - val_loss: 2.0281 - val_categorical_accuracy: 0.6963
# Epoch 19/25
# 16/16 [==============================] - 0s 29ms/step - loss: 2.0378 - categorical_accuracy: 0.6982 - val_loss: 2.0067 - val_categorical_accuracy: 0.6988
# Epoch 20/25
# 16/16 [==============================] - 0s 28ms/step - loss: 2.0298 - categorical_accuracy: 0.6943 - val_loss: 1.9949 - val_categorical_accuracy: 0.7000
# Epoch 21/25
# 16/16 [==============================] - 0s 31ms/step - loss: 2.0028 - categorical_accuracy: 0.7015 - val_loss: 1.9771 - val_categorical_accuracy: 0.7025
# Epoch 22/25
# 16/16 [==============================] - 0s 31ms/step - loss: 1.9930 - categorical_accuracy: 0.6986 - val_loss: 1.9685 - val_categorical_accuracy: 0.7025
# Epoch 23/25
# 16/16 [==============================] - 1s 41ms/step - loss: 1.9764 - categorical_accuracy: 0.7011 - val_loss: 1.9546 - val_categorical_accuracy: 0.7063
# Epoch 24/25
# 16/16 [==============================] - 1s 44ms/step - loss: 1.9605 - categorical_accuracy: 0.7046 - val_loss: 1.9389 - val_categorical_accuracy: 0.7013
# Epoch 25/25
# 16/16 [==============================] - 1s 45ms/step - loss: 1.9487 - categorical_accuracy: 0.7048 - val_loss: 1.9327 - val_categorical_accuracy: 0.7025

# %%
import matplotlib.pyplot as plt

history_dict = history.history
loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']

epochs = range(1, len(loss_values) + 1)
plt.plot(epochs, loss_values, 'g--', label='Training loss')
plt.plot(epochs, val_loss_values, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
plt.clf()
acc_values = history_dict['categorical_accuracy']
val_acc_values = history_dict['val_categorical_accuracy']
plt.plot(epochs, acc_values, 'g--', label='Training Accuracy')
plt.plot(epochs, val_acc_values, 'r', label='Validation Accuracy')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
